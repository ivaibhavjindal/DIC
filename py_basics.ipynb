# %% [markdown]
# <a href="https://colab.research.google.com/github/ivaibhavjindal/DIC/blob/master/py_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AIM**​
# ### To deal with importing and displaying images from Google Drive or PC to Google Colab.

# %% [markdown]
# * Mount your Google Drive to Google Colab

# %%
#  Mount your Google Drive to Google Colab 

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# *  Import an image from Google Drive

# %%
# Import an image from Google Drive 

from PIL import Image
import matplotlib.pyplot as plt

cat = Image.open('gdrive/My Drive/images/cats/1.jpg')
dog = Image.open('gdrive/My Drive/images/dogs/1.jpg')

# %% [markdown]
# * Display the image from Google Drive

# %%
# Display the image from Google Drive  

plt.subplot(1, 2, 1)
plt.imshow(cat)
plt.subplot(1, 2, 2)
plt.imshow(dog)
